# %% [markdown]
# # MAGNET CUBE Solver
#
# This program can solve MAGNET CUBE BLOCKS puzzles.
#
# ![image.png](attachment:226fe067-d771-40bb-b6f4-90a0e79c0ec7.png)
#
# * Run All cells
# * Left click to draw cubes on the left side
# * Ctrl + Left click to delete cubes
# * Change height layer by left & right arrow keys
# * Click the Solve button

# %%
import piplite
await piplite.install(['ipywidgets', 'ipycanvas', 'pythreejs==2.4.1', 'ipyevents', 'python-sat'])

# %%
import pythreejs
from IPython.display import display
from ipywidgets import HBox
from magnetcube import BoxScene, BlockPlacer

# %%
bs = BoxScene()
bp = BlockPlacer(bs)   
HBox([bp.layout, bs.renderer])
